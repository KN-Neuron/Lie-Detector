# %%
import sys

sys.path.append("../../../..")

# %%
from neural_networks.ai.log_analysis import load_logs_by_model

# %%
results = load_logs_by_model("GRU")

# %% [markdown]
# (to jest na wszystkich danych)

# %%
results.sort_values(["test_accuracy"], ascending=False)
# Out:
#    model      run_id  run_counter                               run_name  \
# 1    GRU  1730758943           10  GRU i minionki [NA WSZYSTKICH DANYCH]
# 0    GRU  1730758943            1  GRU i minionki [NA WSZYSTKICH DANYCH]
# 12   GRU  1730758943            7  GRU i minionki [NA WSZYSTKICH DANYCH]
# 10   GRU  1730758943            5  GRU i minionki [NA WSZYSTKICH DANYCH]
# 11   GRU  1730758943            6  GRU i minionki [NA WSZYSTKICH DANYCH]
# 7    GRU  1730758943            2  GRU i minionki [NA WSZYSTKICH DANYCH]
# 13   GRU  1730758943            8  GRU i minionki [NA WSZYSTKICH DANYCH]
# 9    GRU  1730758943            4  GRU i minionki [NA WSZYSTKICH DANYCH]
# 14   GRU  1730758943            9  GRU i minionki [NA WSZYSTKICH DANYCH]
# 8    GRU  1730758943            3  GRU i minionki [NA WSZYSTKICH DANYCH]
# 2    GRU  1730758943           11  GRU i minionki [NA WSZYSTKICH DANYCH]
# 6    GRU  1730758943           15  GRU i minionki [NA WSZYSTKICH DANYCH]
# 3    GRU  1730758943           12  GRU i minionki [NA WSZYSTKICH DANYCH]
# 5    GRU  1730758943           14  GRU i minionki [NA WSZYSTKICH DANYCH]
# 4    GRU  1730758943           13  GRU i minionki [NA WSZYSTKICH DANYCH]
#
#                     timestamp   test_loss  test_accuracy   tmax  \
# 1  2024-11-05 02:19:12.811790    0.520436       0.730799  1.000
# 0  2024-11-04 23:39:00.231180    0.626563       0.643910  1.000
# 12 2024-11-05 01:38:46.306982    0.618600       0.634600  1.000
# 10 2024-11-05 01:13:53.429736    0.707322       0.631497  1.000
# 11 2024-11-05 01:26:20.488422    0.635068       0.615206  1.000
# 7  2024-11-04 23:56:30.264569    0.677037       0.592391  1.997
# 13 2024-11-05 01:52:06.286126    0.679183       0.571761  1.000
# 9  2024-11-05 01:06:19.271696    0.663344       0.568658  1.000
# 14 2024-11-05 02:06:08.573165    0.674501       0.563227  1.000
# 8  2024-11-05 00:42:11.177935    0.689996       0.534523  1.000
# 2  2024-11-05 02:32:15.756117    0.693063       0.515128  1.000
# 6  2024-11-05 03:23:53.883899  242.971512       0.505818  1.000
# 3  2024-11-05 02:45:20.449579    0.743138       0.492630  1.000
# 5  2024-11-05 03:10:48.676652   17.346167       0.490303  1.000
# 4  2024-11-05 02:57:45.095831    2.604848       0.483320  1.000
#
#                               band_to_frequency_range  batch_size  \
# 1   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 0   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 12  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 10  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...         128
# 11  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 7   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 13  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 9   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          32
# 14  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 8   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16
# 2   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 6   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 3   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 5   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 4   {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
#
#     hid_channels        lr  max_epochs
# 1             64    0.0001         500
# 0             64    0.0010         500
# 12            32    0.0010         500
# 10            64    0.0010         500
# 11            16    0.0010         500
# 7             64    0.0010         500
# 13           128    0.0010         500
# 9             64    0.0010         500
# 14           256    0.0010         500
# 8             64    0.0010         500
# 2             64    0.0100         500
# 6             64  100.0000         500
# 3             64    0.1000         500
# 5             64   10.0000         500
# 4             64    1.0000         500
