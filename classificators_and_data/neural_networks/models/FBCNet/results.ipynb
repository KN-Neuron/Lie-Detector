# %%
import sys

sys.path.append("../../../..")

# %%
from neural_networks.ai.log_analysis import load_logs_by_model

# %%
results = load_logs_by_model("FBCNet")

# %%
results.sort_values(["test_accuracy"], ascending=False)
# Out:
#      model      run_id  run_counter                 run_name  \
# 63  FBCNet  1731120155            9           FBCNet - run 7
# 22  FBCNet  1730941668            4           FBCNet - run 2
# 16  FBCNet  1730941668            1           FBCNet - run 2
# 25  FBCNet  1730941668            7           FBCNet - run 2
# 21  FBCNet  1730941668            3           FBCNet - run 2
# ..     ...         ...          ...                      ...
# 19  FBCNet  1730941668           12           FBCNet - run 2
# 18  FBCNet  1730941668           11           FBCNet - run 2
# 17  FBCNet  1730941668           10           FBCNet - run 2
# 15  FBCNet  1730933780            9           FBCNet - run 1
# 68  FBCNet  1731148790            2  FBCNet - run z num S v2
#
#                     timestamp  test_loss  test_accuracy   tmax  \
# 63 2024-11-09 05:48:46.629401   0.449545       0.792844  0.997
# 22 2024-11-07 03:03:03.268322   0.456633       0.789077  1.000
# 16 2024-11-07 02:22:27.552740   0.444801       0.785311  1.000
# 25 2024-11-07 03:32:39.246518   0.480546       0.779661  1.000
# 21 2024-11-07 02:55:47.169953   0.452953       0.777778  1.000
# ..                        ...        ...            ...    ...
# 19 2024-11-07 04:18:39.753190  52.010975       0.483992  1.000
# 18 2024-11-07 04:09:23.103315  25.657999       0.474576  1.000
# 17 2024-11-07 04:00:10.576899   8.668121       0.459510  1.000
# 15 2024-11-07 01:40:15.998703   9.508499       0.457627  1.000
# 68 2024-11-09 14:50:07.068665  13.018186       0.446328  0.997
#
#                                                 freqs  batch_size  num_S  \
# 63  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     64
# 22  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...         128     32
# 16  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     32
# 25  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     32
# 21  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          32     32
# ..                                                ...         ...    ...
# 19  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     32
# 18  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     32
# 17  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64     32
# 15  [[1, 5], [5, 10], [10, 15], [15, 20], [20, 25]...          64     32
# 68  [[1, 10], [10, 20], [20, 30], [30, 40], [40, 5...          64   1024
#
#           lr  max_epochs  stride_factor
# 63    0.0001         500            5.0
# 22    0.0010         500            NaN
# 16    0.0010         500            NaN
# 25    0.0001         500            NaN
# 21    0.0010         500            NaN
# ..       ...         ...            ...
# 19  100.0000         500            NaN
# 18   10.0000         500            NaN
# 17    1.0000         500            NaN
# 15    0.1000         500            NaN
# 68    0.0001         500            5.0
#
# [69 rows x 14 columns]
