# %%
import sys

sys.path.append("../../../..")

# %%
from neural_networks.ai.log_analysis import load_logs_by_model

# %%
results = load_logs_by_model("DGCNN")

# %%
results.sort_values(["test_accuracy"], ascending=False)
# Out:
#    model      run_id  run_counter  \
# 1  DGCNN  1730466911            1
# 0  DGCNN  1730464951            1
# 2  DGCNN  1730904997            1
# 3  DGCNN  1730913143            1
#
#                                             run_name  \
# 1  DGCNN - test po refaktorze (z tmax 1.997) [NA ...
# 0  DGCNN - test po refaktorze [NA WSZYSTKICH DANYCH]
# 2                          DGCNN - na dobrych danych
# 3  DGCNN - na funkcji Marysi z baseline (None, None)
#
#                    timestamp  test_loss  test_accuracy   tmax  \
# 1 2024-11-01 14:31:14.778252   0.487260       0.885870  1.997
# 0 2024-11-01 13:58:28.500367   0.667573       0.840962  1.000
# 2 2024-11-06 16:22:54.451947   0.823096       0.824528  1.997
# 3 2024-11-06 18:50:59.068375   0.814586       0.805660  1.997
#
#                              band_to_frequency_range  batch_size  num_layers  \
# 1  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16           2
# 0  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16           2
# 2  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16           2
# 3  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16           2
#
#    hid_channels     lr  max_epochs
# 1            32  0.001         500
# 0            32  0.001         500
# 2            32  0.001         500
# 3            32  0.001         500
